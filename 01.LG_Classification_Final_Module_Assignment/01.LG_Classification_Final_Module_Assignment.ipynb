# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Chronic Kidney Disease (CKD).csv")
dataset
# Out:
#            age         bp sg  al  su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c   3   0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c   2   0  normal    normal  notpresent
# 2     4.000000  76.459948  a   1   0  normal    normal  notpresent
# 3     5.000000  76.459948  d   1   0  normal    normal  notpresent
# 4     5.000000  50.000000  c   0   0  normal    normal  notpresent
# ..         ...        ... ..  ..  ..     ...       ...         ...
# 394  51.492308  70.000000  a   0   0  normal    normal  notpresent
# 395  51.492308  70.000000  c   0   2  normal    normal  notpresent
# 396  51.492308  70.000000  c   3   0  normal    normal  notpresent
# 397  51.492308  90.000000  a   0   0  normal    normal  notpresent
# 398  51.492308  80.000000  a   0   0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# ...

# %%
dataset = pd.get_dummies(dataset,dtype=int, drop_first=True)
dataset
# Out:
#            age         bp  al  su         bgr          bu        sc  \
# 0     2.000000  76.459948   3   0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948   2   0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948   1   0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948   1   0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000   0   0  148.112676   25.000000  0.600000
# ..         ...        ...  ..  ..         ...         ...       ...
# 394  51.492308  70.000000   0   0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000   0   2  220.000000   68.000000  2.800000
# 396  51.492308  70.000000   3   0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000   0   0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000   0   0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
# Axis = 0 (Row) By defualt, to specify the Column which is to be deleted Axis=1 should be mentioned. 
#dataset = dataset.drop(['appet_poor'], axis=1)
#dataset

# %%
dataset["classification_yes"].value_counts()
# Out:
# classification_yes
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
independent = dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dependent = dataset["classification_yes"]

# %%
independent.shape
# Out:
# (399, 27)

# %%
dependent
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 394    1
# 395    1
# 396    1
# 397    1
# 398    0
# Name: classification_yes, Length: 399, dtype: int32

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

#Here the fit.transform function Standardize the Undefined data to Defined Data and make it to be saved in X_train
X_train = sc.fit_transform(X_train)

#Here the transform function uses the process occurred in fit.transform function for the input X_test and make it to be saved in X_train
X_test = sc.transform(X_test)

X_train
# Out:
# array([[ 0.48681432,  1.79924415, -0.68384276, ...,  0.51639778,
#         -0.52223297, -0.44519456],
#        [ 0.30305399,  0.26080096, -0.68384276, ...,  0.51639778,
#         -0.52223297, -0.44519456],
#        [-0.61574769, -0.50842064, -0.68384276, ...,  0.51639778,
#         -0.52223297, -0.44519456],
#        ...,
#        [-0.43198735,  0.26080096, -0.68384276, ...,  0.51639778,
#         -0.52223297, -0.44519456],
#        [-1.35078903,  0.26080096, -0.68384276, ...,  0.51639778,
#         -0.52223297, -0.44519456],
#        [-0.06446668, -1.27764223, -0.68384276, ...,  0.51639778,
#         -0.52223297, -0.44519456]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV #Here cv refers to Cross Validation

#Creating a Dictionary for Playable Parameters
param_grid = {'solver':['newton-cg','lbfgs','liblinear','saga'], 'penalty':['l2']}

#if refit = false then final model will be considered as Last Combination of parameter_grid like (linear,3000,scale)
#n_jobs = -1 refers to Run all the Models Parallely
#refit = True -> Best Value from the GridSearch will be saved in Grid for Model Creation
#scoring = 'f1_weighted' -> It is used for both Balanced and Imbalanced data and can be taken into account for validation instead of Precision/Recall/Accuracy
grid = GridSearchCV(LogisticRegression(), param_grid, refit = True, verbose = 3, n_jobs = -1, scoring = 'f1_weighted')

#All the above steps are called "Procedure Load"

#Model Creation
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'penalty': ['l2'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'saga']},
#              scoring='f1_weighted', verbose=3)

# %%
result = grid.cv_results_

y_pred = grid.predict(X_test)

from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)

from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)
print(clf_report)
# Out:
# [[51  0]
#  [ 1 81]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        51
#            1       1.00      0.99      0.99        82
#
#     accuracy                           0.99       133
#    macro avg       0.99      0.99      0.99       133
# weighted avg       0.99      0.99      0.99       133

# %%
#clf_report.__add__

# %%
# Read Excel and select a single cell (and make it a header for a column)
#usecols = Column A,B,C etc
#header = No or Order of Row
filename = 'CKD_Input Test Data.xlsx'

ageDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "A", header = 1, nrows=0)

# Extract a value from a list (list of headers)
age = int(ageDataList.columns.values[0])
print("Given Input Range Between 0 To 150 for Column - age :", age)

bpDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "B", header = 1, nrows=0)
bp = float(bpDataList.columns.values[0])
print("Given Input Range Between 0 To 200 for Column - bp :", bp)

sgDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "C", header = 1, nrows=0)
sg = int(sgDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - sg :", sg)

alDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "D", header = 1, nrows=0)
al = int(alDataList.columns.values[0])
print("Given Input Range Between 0 To 10 for Column - al :", al)

suDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "E", header = 1, nrows=0)
su = int(suDataList.columns.values[0])
print("Given Input Range Between 0 To 10 for Column - su :", su)
# Out:
# Given Input Range Between 0 To 150 for Column - age : 23
# Given Input Range Between 0 To 200 for Column - bp : 6.504518753990953
# Given Input Range Between (Yes = 1 Or No = 0) for Column - sg : 5
# Given Input Range Between 0 To 10 for Column - al : 4
# Given Input Range Between 0 To 10 for Column - su : 8

# %%
rbcDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "F", header = 1, nrows=0)
rbc = int(rbcDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - rbc :", rbc)
# Out:
# Given Input Range Between (Yes = 1 Or No = 0) for Column - rbc : 0

# %%
pcDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "G", header = 1, nrows=0)
pc = int(pcDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - pc :", pc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 pcDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "G", header = 1, nrows=0)
# ----> 2 pc = int(pcDataList.columns.values[0])
#       3 print("Given Input Range Between (Yes = 1 Or No = 0) for Column - pc :", pc)
#
# ValueError: invalid literal for int() with base 10: '0.1'

# %%
pccDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "H", header = 1, nrows=0)
pcc = int(pccDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - pcc :", pcc)

baDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "I", header = 1, nrows=0)
ba = int(baDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - ba :", ba)

bgrDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "J", header = 1, nrows=0)
bgr = float(bgrDataList.columns.values[0])
print("Given Input Range Between 0 To 500 for Column - bgr :", bgr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 pccDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "H", header = 1, nrows=0)
# ----> 2 pcc = int(pccDataList.columns.values[0])
#       3 print("Given Input Range Between (Yes = 1 Or No = 0) for Column - pcc :", pcc)
#       5 baDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "I", header = 1, nrows=0)
#
# ValueError: invalid literal for int() with base 10: '0.2'

# %%
budataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "K", header = 1, nrows=0)
bu = float(budataList.columns.values[0])
print("Given Input Range Between 0 To 500 for Column - bu :", bu)

scDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "L", header = 1, nrows=0)
sc = float(scDataList.columns.values[0])
print("Given Input Range Between 0 To 100 for Column - sc :", sc)

sodDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "M", header = 1, nrows=0)
sod = float(sodDataList.columns.values[0])
print("Given Input Range Between 0 To 200 for Column - sod :", sod)

potDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "N", header = 1, nrows=0)
pot = float(potDataList.columns.values[0])
print("Given Input Range Between 0 To 100 for Column - pot :", pot)

hrmoDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "O", header = 1, nrows=0)
hrmo = float(hrmoDataList.columns.values[0])
print("Given Input Range Between 0 To 20 for Column - hrmo :", hrmo)
# Out:
# Given Input Range Between 0 To 500 for Column - bu : 292.45615009377315
# Given Input Range Between 0 To 100 for Column - sc : 86.54892077671079
# Given Input Range Between 0 To 200 for Column - sod : 93.93804546336726
# Given Input Range Between 0 To 100 for Column - pot : 35.6099938865435
# Given Input Range Between 0 To 20 for Column - hrmo : 8.523998936354236

# %%
pcvDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "P", header = 1, nrows=0)
pcv = float(pcvDataList.columns.values[0])
print("Given Input Range Between 0 To 100 for Column - pcv :", pcv)

wcDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "Q", header = 1, nrows=0)
wc = int(wcDataList.columns.values[0])
print("Given Input Range Between 2,000 To 50,000 for Column - wc :", wc)

rcDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "R", header = 1, nrows=0)
rc = float(rcDataList.columns.values[0])
print("Given Input Range Between 0 To 10 for Column - rc :", rc)

htnDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "S", header = 1, nrows=0)
htn = int(htnDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - htn :", htn)

dmDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "T", header = 1, nrows=0)
dm = int(dmDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - dm :", dm)
# Out:
# Given Input Range Between 0 To 100 for Column - pcv : 12.111159042984967
# Given Input Range Between 2,000 To 50,000 for Column - wc : 7404
# Given Input Range Between 0 To 10 for Column - rc : 4.335606527608727
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 14
#      11 print("Given Input Range Between 0 To 10 for Column - rc :", rc)
#      13 htnDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "S", header = 1, nrows=0)
# ---> 14 htn = int(htnDataList.columns.values[0])
#      15 print("Given Input Range Between (Yes = 1 Or No = 0) for Column - htn :", htn)
#      17 dmDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "T", header = 1, nrows=0)
#
# ValueError: invalid literal for int() with base 10: '0.3'

# %%
cadDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "U", header = 1, nrows=0)
cad = int(cadDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - cad :", cad)

appetDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "V", header = 1, nrows=0)
appet = int(appetDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - appet :", appet)

peDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "W", header = 1, nrows=0)
pe = int(peDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - pe :", pe)

aneDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "X", header = 1, nrows=0)
ane = int(aneDataList.columns.values[0])
print("Given Input Range Between (Yes = 1 Or No = 0) for Column - ane :", ane)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 cadDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "U", header = 1, nrows=0)
# ----> 2 cad = int(cadDataList.columns.values[0])
#       3 print("Given Input Range Between (Yes = 1 Or No = 0) for Column - cad :", cad)
#       5 appetDataList = pd.read_excel(filename, 'CKD', index_col=None, usecols = "V", header = 1, nrows=0)
#
# ValueError: invalid literal for int() with base 10: '0.5'

# %%
grid.predict([["age", "bp", "sg", "al", "su", "rcb", "pc", "pcc", "ba", "bgr", "bu", "sc", "sod", "pot",	
"hrmo",	"pcv",	"wc",	"rc",	"htn",	"dm",	"cad",	"appet","pe","ane"]])

# %%
#dir(clf_report)

# %%
# Naming the Model with its extension .sav
import pickle
filename = "finalized_model_Logistic_classification_Assignment.sav"

#Model will be saved in respective path, once after the below Code Execution
# Keyword - wb refers to "write binary"
pickle.dump(classifier,open(filename,'wb'))

# %%
# Load the Saved Model and check the same to send it for Phase-02 (Deployment)
# # Keyword - rb refers to "read binary"

loaded_model=pickle.load(open("finalized_model_Logistic_classification_Assignment.sav",'rb'))
result = loaded_model.predict([[age_input,salary_input,sex_male_input]]) 
result
